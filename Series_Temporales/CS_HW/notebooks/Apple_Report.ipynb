# %% [markdown]
# # Series Temporales HW 01: Predicción de Ingresos de Apple
# **Predicción de Series Temporales <br>
# Carlos Eduardo Sebastiani** <br>
# 2 de Noviembre del 2021

# %% [markdown]
# ## Objetivos:
# Los objetivos son entender las ventas de Apple y aplicar correctamente la estimación y selección de modelos ARIMA y ETS, y comparar las predicciones.
#
# Para esto será necesario responder a una serie de preguntas que nos permitirán identificar variables y características de la serie temporal, ayudandonos a hacer una evaluación acerca de la series.

# %% [markdown]
# ## Ventas de Apple
# Las ventas de Apple han crecido a lo largo del tiempo, como se puede observar, después del 2008 tuvo un crecimiento vertiginoso, esto se debe a que es el momento en que se lanza el primer Iphone, producto estrella de la compañia a partir de ahí el nivel de innovación no ha ido a menos y en el 2011, con la muerte de su fundador y el lanzamiento de iPads, Macbooks y Siri la empresa sigue creciendo

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2010.07.50.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2010.07.50.png)

# %% [markdown]
# ## Estacionariedad y estacionalidad
#
# Para poder entender los modelos que vamos a utilizar, es necesario entender la serie.
#
# Lo primero que estudiaremos será la **estacionariedad de la serie** :
#
# -  Muestran cambios en media y/o en varianza
# -  Pueden mostrar una tendencia
# -  Pueden presentar efectos estacionales periódicos en el tiempo
#
# Si hacemos un análisis de las medias en períodos de un año, se observa lo siguiente:

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2010.15.15.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2010.15.15.png)

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2011.09.09.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2011.09.09.png)

# %% [markdown]
# Apple presenta **medias y varianzas que van incrementando, creando una tendencia de crecimiento** en el tiempo, también presenta un **comporamiento estacional** en el que el Q1 en años fiscales(Q terminado en diciembre) tiene más ventas que el resto del año, esto podría deberse al hecho que apple saca sus productos en septiembre y sus productos sufren un incremento de ventas debido a los períodos de fiesta y de bonos laborales de fin de año.
#
# Entendiendo estas características podemos concluír que **las ventas de Apple son una serie temporal no estacionaria**

# %% [markdown]
# ## Ventas Anuales de Apple

# %% [markdown]
# Los datos anuales de las ventas anuales de Apple también revelan la tendencia a aumentar con el tiempo, veamos el siguiente gráfico:

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2011.16.06.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2011.16.06.png)

# %% [markdown]
# Podemos ver que hay años fiscales en los que ha llegado ha tener un creicimiento de hasta 60%. De hecho la media de crecimiento es de un poco máx de 17%, lo cual claramente indica el crecimiento importante de la empresa y confirma la tendencia.

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2011.25.42.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2011.25.42.png)

# %% [markdown]
# ## Modelos de Predicción
#
# Para este caso se utilizarán dos modelos, un modelo ETS y un modelo ARIMA. La diferencia entre los dos no parece significativamente alta.

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2012.35.20.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2012.35.20.png)

# %% [markdown]
# A pesar de las diferencias no ser significativamente altas, **el modelo que mejor ha predecido es el modelo ARIMA**,
# pues este tiene un menor error porcentual medio abosulo:
#
# mape_ets = 0.18651410968558557 <br>
# mape_arima =0.156789696433304

# %% [markdown]
# ## Efecto COVID
# Ahora que tenemos un modelo que estima, podemos observar que las estimaciones de nuestros modelos han estado por debajo de los valores reales, esto podría deberse al período de alta volatilidad y cambios en el mundo debido al COVID-19, en el que Apple no se ha quedado atrás.
#
# Si comparamos las estimaciones del modelo ARIMA con los datos reales vemos que las ventas de apple ha llegado a ser inncluso un 40% más que lo esperado

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2012.43.41.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2012.43.41.png)

# %% [markdown]
# ## Predicciones
# Ahora que entendemos el la serie y el negocio, podemos evaluar las predicciones de los modelos en base a nuestro conocimiento de negocio y a como funcionan los modelos de que hemos utilizado.
#
# En el siguiente cuadro veremos las predicciones para los años 2021 y 2022, tanto las de nuestro modelo ARIMA como las de Barclays

# %% [markdown]
# ![Captura%20de%20pantalla%202021-11-01%20a%20las%2013.52.26.png](attachment:Captura%20de%20pantalla%202021-11-01%20a%20las%2013.52.26.png)

# %% [markdown]
# Se espera que para el año 2021 Apple realice unas ventas de $375k mm, sin embargo Barclays predice 368k mm, esto es un 1.75% menos que nuestro modelo, para este dato, podemos aceptar que las ventas estarán al rededor de esos números y no esperamos diferencias signficativas
#
# Con respecto a las ventas del 2022, nuestro modelo, predice unas ventas de 473k mm, mientras que Barclays es más conservador y estima unas ventas de $378k mm, esta es una diferencia de casi 20%. Llegados a este punto, vale al pena comentar que nuestro modelo de media erra aprox un 15% y no sabemos como ha sido el desempeño durante el testeo del modelo de Barclays.
#
#
# Por otra parte, cuando vemos los crecimientos, de media han crecido un 17% que parece poco representativo, por lo tanto comparando lo compararemos con la media del **crecimiento de los últimos 5 años 9.97%**. Para el 2022 Barclays predice un crecimiento de 2.62%, mientras que nuestro modelo da un crecimineto de 26% que parece exagerado, cuando lo comparamos con la media de crecimiento de los últimos 5 años.

# %% [markdown]
# ## Conclusiones
#
# 1.  Las ventas de Apple tienen un crecimiento importante y presentan una tendencia positiva, con media y varianza que varian con el tiempo por lo que se comportan de forma no estacionaria. La serie temporal también presenta estacionalidad, teniendo un crecimineto una media más alta duante el FY Q1
# 2. Las ventas anuales de Apple han crecido de forma envidiable, sobretodo a partir del 2008/2012
# 3. Apple ha sido una de las empresas que han tenido crecimiento durante el COVID, batiendo las expectativas de crecimineto en ventas.
# 4. Los modelos ARIMA y ETS se han utilizado para intentar predecir las ventas de Apple, sin embargo **se considera que el porcentaje de error es alto y que los modelos no son del todo fiables**.
# 5.  Se considera que el modelo de Barclays, aún siendo más considerado, solo predice un crecimiento del 2.62% para el 2022 que parece ser consevador cuando se tiene un entendimiento del negocio de Apple y se comparan con el crecimineto de los últimos 5 años.
