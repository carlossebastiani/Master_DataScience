# %% [markdown]
#  # Predicción de Series Temporales
#  # Predicción Ingresos Coca-Cola (KO)
#  ## Modelos ARIMA

# %%
# Styling notebook
from IPython.core.display import HTML
def css_styling():
    styles = open("style.css", "r",encoding="utf-8").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# /* =========
# CSS quant.css
# Para usar en rmarkdown
# (c) Ricardo A. Queralt
# ====== */
#
# p {line-height: 1.5em;}
# b {color: rgba(255, 69, 0, 0.7)}
#
# mytag {
#     font-weight: bold;
#     color: red;
#     background-color: yellow;
# }
#
#
# @font-face {
#   font-family: 'Muli';
#   font-style: normal;
#   font-weight: 300;
#   src: url(https://fonts.gstatic.com/s/muli/v22/7Aulp_0qiz-aVz7u3PJLcUMYOFnOkEk30e6fwniDtzM.woff) format('woff');
#   unicode-range: U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+2000-206F, U+2074, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;
# }
#
# body {
#   font-family: 'Muli';
#   font-weight: 300;
# }
# p{
#     font-family: 'Muli';
#     margin-bottom: 30px;
# }
#
# ul{
#     font-family: 'Muli';
#     margin-bottom: 30px;
# }
#
# li{
#     font-family: 'Muli';
#       margin-bottom: 10px;
# }
#
# ol{
#     font-family: 'Muli';
#     margin-bottom: 30px;
# }
#
# h1, h2, h3,h4 {
#     font-family: 'Whitney';
#     font-variant: small-caps;
# }
#
#
#
#
#
#
# h1 {
#   color: rgba(255, 69, 0, 0.7);
# }
#
# strong {
#      color: rgba(255, 69, 0, 0.7);
#      font-weight: 400;
# }
#
# h2 {
#   color: rgba(49, 199, 58, 0.5);
#   font-weight: bold;
#   font-variant: small-caps;
# }
#
# h3 {
#   color: rgba(49, 199, 58, 0.5);
#   font-weight: bold;
#   text-decoration: underline;
# }
#
#
# h4 {
#   color: rgba(49, 199, 58, 0.5);
#
# }
#
# .redbox {
#   border: 1px solid rgb(0, 102, 102);
#   padding: 10px 10px;
#   background-color: #ffbbbb;
#     border-radius: 5px;
# }
#
# .instructions {
#     margin-top: 30px;
#     margin-bottom: 30px;
#     padding: 10px 10px;
#     border: 1px solid rgb(0, 102, 102);
#     border: 1px solid rgba(0, 102, 102, 0.2);
#     border-radius: 5px;
#     color: rgb(0, 102, 102);
#     color: rgba(0, 102, 102, 0.8);
#     background: rgb(204, 255, 255) !important;
#     background: rgba(204, 255, 255, 0.1) !important;
# }
#
# .exercise {
#     position: relative; /* Create a positioning context */
#     margin: 0 0 10px 0; /* Give each list item a left margin to make room for the numbers */
#     padding: 10px 30px; /* Add some spacing around the content */
#     border-top: 2px solid #35CD4B;
#     background: rgb(49, 199, 58) !important;
#     background: rgba(49, 199, 58, 0.1)!important;
# }
#
# .redcuadro {
#     position: relative; /* Create a positioning context */
#     margin: 0 0 10px 0; /* Give each list item a left margin to make room for the numbers */
#     padding: 10px 30px; /* Add some spacing around the content */
#     border-top: 2px solid rgba(240, 7, 58, 0.66);
#     background: #ffbbbb !important;
#    /* background: rgba(240, 7, 58, 0.66)!important; */
# }
#
# .imagen {
#     position: relative; /* Create a positioning context */
#     margin: 0 0 10px 0; /* Give each list item a left margin to make room for the numbers */
#     padding: 10px 30px; /* Add some spacing around the content */
#     border-top: 2px solid rgb(0, 102, 102);
#     background: rgb(204, 255, 255) !important;
#     background: rgba(204, 255, 255, 0.3) !important;
# }
#
#
#
# .center {
#   text-align: center;
# }
# .azul{
#   color: rgb(49, 199, 58);
# }
# .infobox {
#   padding: 1em 1em 1em 4em;
#   margin-bottom: 10px;
#   border: 2px solid orange;
#   border-radius: 10px;
#   background: #f5f5f5 5px center/3em no-repeat;
# }
#
# ol {
#   list-style: none;
#   counter-reset: my-awesome-counter;
# }
# ol li {
#   counter-increment: my-awesome-counter;
# }
#
# ol li::before {
#   content: counter(my-awesome-counter) ". ";
#   color: rgba(255, 69, 0, 0.7);
#   font-weight: bold;
# }
#
# ul {list-style: none}
#
# ul {
#     list-style: none; /* Remove default bullets */
#   }
#
#
# ul li::before {content: "★";
#   color: rgba(255, 69, 0, 0.7);
#   display: inline-block;
#   width: 1em;
#   margin-left: -0.45em;
#   text-indent: -1em;
#   }
#
#
# .hr1 {
#     display: block;
#     height: 6px;
#     border: 0;
#     border-top: 4px solid rgba(255, 69, 0, 0.7);
#     margin: 1em 0;
#     padding: 0;
# }
#
#
# .hr2 {
#     display: block;
#     height: 6px;
#     border: 0;
#     border-top: 4px solid rgba(49, 199, 58, 0.5);
#     margin: 1em 0;
#     padding: 0;
# }
#
#
# .hr2d {
#     display: block;
#     height: 6px;
#     border: 0;
#     border-top: 2px dotted rgba(49, 199, 58, 0.5);
#     margin: 1em 0;
#     padding: 0;
# }
#
#
# .hr2b {
#     position: relative; /* Create a positioning context */
#     margin: 0 0 10px 0; /* Give each list item a left margin to make room for the numbers */
#     padding: 10px 30px; /* Add some spacing around the content */
#     border-top: 2px dotted rgba(49, 199, 58, 0.5);
# }
#
# </style>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  # Introducción
#
#  <div class="exercise">
#
#  - El objetivo es predecir las ventas de Coca-Cola.
#
#  - Se realizan diferentes predicciones de las ventas de Coca-Cola.
#
#  - Se tienen datos trimestrales desde 1991-1T hasta 2021-2T.
#
#  - Se dejan fuera de la estimación los ocho últimos trimestres para seleccionar el mejor modelo.
#
#  - Se uestiman los modelos ARIMA
#
#  </div>

# %%
# Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Read Data
ko_df = pd.read_csv('ko (2).csv',sep=';')
ko_df['Fecha'] = pd.to_datetime(ko_df['Fecha'],format="%Y%m%d")
ko_df = ko_df.set_index('Fecha')
ko_df.head()
# Out:
#             Ingresos
# Fecha
# 2021-06-03     10129
# 2021-03-03      9020
# 2020-12-31      8611
# 2020-09-26      8652
# 2020-06-27      7150

# %% [markdown]
#  <div class="redcuadro">
#
#  Convertimos los datos en trimestrales
#
#  </div>

# %%
# Resample to Quarterly I
ko_ts=ko_df.resample("q").last()
ko_ts.tail()
# Out:
#             Ingresos
# Fecha
# 2020-06-30      7150
# 2020-09-30      8652
# 2020-12-31      8611
# 2021-03-31      9020
# 2021-06-30     10129

# %%
# Resample to Quarterly II
# SKtime format
ko_ts_q=ko_df['Ingresos'].astype('float64').to_period('Q').sort_index()
ko_ts_q.tail()
# Out:
# Fecha
# 2020Q2     7150.0
# 2020Q3     8652.0
# 2020Q4     8611.0
# 2021Q1     9020.0
# 2021Q2    10129.0
# Freq: Q-DEC, Name: Ingresos, dtype: float64

# %% [markdown]
#  # Solución
#
#  ## Graficar los Ingresos
#  <div class="hr2"> </div>
#  - Tendencia -> No estacionario
#  - Componente Estacional
#  - Varianza no constante

# %%
# Plot Data
# Use seaborn style defaults and set the default figure size

import seaborn as sns
sns.set(rc={'figure.figsize':(11, 4)})
ax = ko_ts.plot(marker='o', linestyle='-')
ax.set_ylabel('Ventas Coca Cola');

# %%
# Plot Data
# Use Sktime style 
from sktime.utils.plotting import plot_series
plot_series(ko_ts_q, labels=["Ventas"])

# %% [markdown]
#  # No estacionariedad en Varianza
#
#  <div class="hr2"> </div>
#
#  ## Calculamos la transformacion logarítmica de la **Serie Original**

# %%
# Log Transformer Function
from sktime.transformations.series.boxcox import LogTransformer

# %%
# Apply Log Transformer

transformer = LogTransformer()
log_ko_ts= transformer.fit_transform(ko_ts_q)
log_ko_ts.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7z/bfwz_ql10kg4l7yw6jx3nk180000gn/T/ipykernel_32769/1365249005.py in <module>
#       2
#       3 transformer = LogTransformer()
# ----> 4 log_ko_ts= transformer.fit_transform(ko_ts_q)
#       5 log_ko_ts.tail()
#
# NameError: name 'ko_ts_q' is not defined

# %%
# Plot Log Data
ax = log_ko_ts.plot(marker='o', linestyle='-')
ax.set_ylabel('Ventas Coca Cola')
ax.set_title('Ventas Coca Cola: Transformación LOG')

# %%
# Plot Log Data
fig, ax =plot_series(log_ko_ts, labels=["Ventas"])
ax.set_title('Ventas Coca Cola: Transformación LOG')

# %% [markdown]
#  # No estacionariedad en Varianza
#
#  <div class="hr2"> </div>
#  ## Comparamos la transformacion logarítmica de la **Serie Original** y la **Serie en Logs**

# %%
# Plot Log Data & Original Data
fig, ax =plot_series(ko_ts_q, labels=["Ventas"])
ax.set_title('Ventas Coca Cola: Serie Original')
fig, ax =plot_series(log_ko_ts, labels=["Ventas"])
ax.set_title('Ventas Coca Cola: Transformación LOG')

# %% [markdown]
#  # Autocorrelación
#
#  <div class="hr2"> </div>
#
#  ## Calculamos la Autocorrelación de la **Serie en Logs**

# %%
# Autocorrelation Fuction Package
from sktime.utils.plotting import plot_correlations

# %%
# Autocorrelation Fuction Original Time Series
plot_correlations(log_ko_ts)
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:ylabel='Ingresos'>,
#         <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# Difference Fuction Package
from sktime.transformations.series.difference import Differencer

# %%
# Autocorrelation Fuction
# d=1; D=0; S=4
# 
transf_diff=Differencer(lags=[1])
plot_correlations(transf_diff.fit_transform(log_ko_ts))
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:ylabel='Ingresos'>,
#         <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# Autocorrelation Fuction
# d=0; D=1; S=4
# 
transf_diff=Differencer(lags=[4])
plot_correlations(transf_diff.fit_transform(log_ko_ts))
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:ylabel='Ingresos'>,
#         <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %%
# Autocorrelation Fuction
# d=1; D=1; S=4
# 
transf_diff=Differencer(lags=[1,4])
plot_correlations(transf_diff.fit_transform(log_ko_ts))
# Out:
# (<Figure size 864x576 with 3 Axes>,
#  array([<AxesSubplot:ylabel='Ingresos'>,
#         <AxesSubplot:title={'center':'Autocorrelation'}>,
#         <AxesSubplot:title={'center':'Partial Autocorrelation'}>],
#        dtype=object))

# %% [markdown]
#  # Modelos ARIMA

# %% [markdown]
#  <div class="redcuadro">
#
#  Vamos a separar la muestra en la parte de estiamción (Training) y la parte de predicción/Verificación (Testing). Quitamos 8 trimestres. <br><br>
#
#  Vamos a predecir 8 periodos  (h=8)<br><br>
#
#  </div>

# %%
# Sktime fucntions
# Forecast horizon and Split function 
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.model_selection import temporal_train_test_split

# %%
# Select Train & test sample
# we will try to forecast y_test from y_train
# plotting for illustration
# original and log samples
y_train, y_test = temporal_train_test_split(y =ko_ts_q, test_size=8)
log_y_train, log_y_test = temporal_train_test_split(y =log_ko_ts, test_size=8)
plot_series(y_train, y_test, labels=["Train", "Test"])
# Time Series Size
print(y_train.shape[0], y_test.shape[0])
# Out:
# 114 8

# %%
# Forecast Horizon
fh = np.arange(len(y_test)) + 1  # forecasting horizon
fh
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
# Sktime Auto ARIMA Function
from sktime.forecasting.arima import AutoARIMA

# %%
#  Auto ARIMA Model

forecaster = AutoARIMA(sp=4,suppress_warnings=True)
forecaster.fit(log_y_train)
# Out:
# AutoARIMA(sp=4, suppress_warnings=True)

# %%
#  Auto ARIMA Model Summary
print(forecaster.summary())

## esta diciendo que el modelo qeu ha elejido es la tasa de variación logaritmica en función de un autoregresivo de orden 1 estacional, 
## de 4 períodos anteriores y del error de hace 4 períodos
## si quieres explicar el crecimiento de las ventas, debes tener en cuenta las ventas del mismo cuatri de hace un año. (el crecimiento)
## y el error que conseguiste de otro período. 
## o 0.60 sabemos entonces que es ruido blanco
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  114
# Model:             SARIMAX(0, 1, 0)x(1, 0, [1], 4)   Log Likelihood                 167.994
# Date:                             Sat, 02 Oct 2021   AIC                           -329.988
# Time:                                     07:04:17   BIC                           -321.806
# Sample:                                          0   HQIC                          -326.668
#                                              - 114
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L4        0.9963      0.004    260.854      0.000       0.989       1.004
# ma.S.L4       -0.8225      0.071    -11.632      0.000      -0.961      -0.684
# sigma2         0.0027      0.000     17.822      0.000       0.002       0.003
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.28   Jarque-Bera (JB):               540.84
# Prob(Q):                              0.60   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.61   Skew:                             1.80
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.09
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#  Auto ARIMA Forecast
log_y_pred = forecaster.predict(fh)
log_y_pred
# Out:
# 2019Q3    9.153887
# 2019Q4    9.064480
# 2020Q1    9.061448
# 2020Q2    9.209393
# 2020Q3    9.153447
# 2020Q4    9.064368
# 2021Q1    9.061348
# 2021Q2    9.208749
# Freq: Q-DEC, dtype: float64

# %%
#  Auto ARIMA Forecast
# Original Time series (Invert log transformation)
np.exp(log_y_pred)
# Out:
# 2019Q3    9451.107910
# 2019Q4    8642.780173
# 2020Q1    8616.617754
# 2020Q2    9990.533238
# 2020Q3    9446.946705
# 2020Q4    8641.818442
# 2021Q1    8615.755081
# 2021Q2    9984.094440
# Freq: Q-DEC, dtype: float64

# %%
# Sktime fucntions
# Forecast Accuracy MAPE & MSE & RMSE
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.performance_metrics.forecasting import MeanSquaredError

# %%
# Forecast Accuracy
# MAPE
mean_absolute_percentage_error(log_y_test, log_y_pred)
# Out:
# 0.007472426631496381

# %%
# Forecast Accuracy
# MAPE 
# Orignal Time Serie

mean_absolute_percentage_error(y_test, np.exp(log_y_pred))
# Out:
# 0.06735489594298401

# %%
# Forecast Accuracy
#Mean Squared Error
rmse = MeanSquaredError(square_root=True)
rmse(log_y_test, log_y_pred)
# Out:
# 0.12465023984181178

# %%
# Forecast Accuracy
#Mean Squared Error
rmse = MeanSquaredError(square_root=True)
rmse(y_test, np.exp(log_y_pred))
# Out:
# 1064.7834541819277

# %%
# Forecast Accuracy Plot
# Plotting predictions and past data
plot_series(y_train, np.exp(log_y_pred),y_test, labels=["KO", "KO pred", "KO REAL"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='Ingresos'>)

# %%
# Forecast Accuracy Plot
# Plotting predictions and past data
# Zoom 2013 -2021
plot_series(y_train["2013":], np.exp(log_y_pred),y_test, labels=["KO", "KO pred", "KO REAL"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='Ingresos'>)

# %%
# Save Plot
plot_series(y_train["2013":], np.exp(log_y_pred),y_test, labels=["KO", "KO pred", "KO REAL"])
plt.savefig('img/04/predict-AutoARIMA-airline-data-plot.png',
            dpi=300, bbox_inches='tight')
plt.close('all')

# %% [markdown]
#  <div class="redcuadro">
#
#  Vamos a predecir 6 periodos  (h=6), lo que resta del 2021 y el 2022<br><br>
#
#  </div>

# %%
# Forecast Horizon
fh = np.arange(6) + 1  # forecasting horizon
fh
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
#  Auto ARIMA Model

forecaster = AutoARIMA(sp=4,suppress_warnings=True)
forecaster.fit(log_ko_ts)
# Out:
# AutoARIMA(sp=4, suppress_warnings=True)

# %%
#  Auto ARIMA Model Summary
print(forecaster.summary())

## los primeros son lo regulares. el segundo parentesis es con el año y el primero es con el trimestre.
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  122
# Model:             SARIMAX(0, 1, 0)x(1, 0, [1], 4)   Log Likelihood                 156.355
# Date:                             Tue, 26 Oct 2021   AIC                           -306.710
# Time:                                     17:20:10   BIC                           -298.323
# Sample:                                          0   HQIC                          -303.304
#                                              - 122
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L4        0.9911      0.008    119.849      0.000       0.975       1.007
# ma.S.L4       -0.7998      0.080    -10.006      0.000      -0.956      -0.643
# sigma2         0.0041      0.000     16.701      0.000       0.004       0.005
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.31   Jarque-Bera (JB):               441.36
# Prob(Q):                              0.58   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.47   Skew:                             0.30
# Prob(H) (two-sided):                  0.01   Kurtosis:                        12.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#  Auto ARIMA Forecast
log_y_pred = forecaster.predict(fh)
log_y_pred
# Out:
# 2021Q3    9.215661
# 2021Q4    9.150373
# 2022Q1    9.150608
# 2022Q2    9.235583
# 2022Q3    9.228152
# 2022Q4    9.163444
# Freq: Q-DEC, dtype: float64

# %%
#  Auto ARIMA Forecast
# Original Time series (Invert log transformation)
np.exp(log_y_pred)
# Out:
# 2021Q3    10053.344352
# 2021Q4     9417.956466
# 2022Q1     9420.166506
# 2022Q2    10255.637080
# 2022Q3    10179.712691
# 2022Q4     9541.863852
# Freq: Q-DEC, dtype: float64

# %%
# Forecast Accuracy Plot
# Plotting predictions and past data
plot_series(ko_ts_q, np.exp(log_y_pred), labels=["KO", "KO pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='Ingresos'>)

# %%
# Forecast Accuracy Plot
# Plotting predictions and past data
plot_series(ko_ts_q["2016":], np.exp(log_y_pred), labels=["KO", "KO pred"])
# Out:
# (<Figure size 1152x288 with 1 Axes>, <AxesSubplot:ylabel='Ingresos'>)
